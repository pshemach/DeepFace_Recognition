# %%
from deepface import DeepFace
import matplotlib.pyplot as plt

# %%
face = DeepFace.extract_faces(  
    '../data/images_1.jpg',
    detector_backend='opencv'
)

# %%
face
# Out:
# [{'face': array([[[0.43137255, 0.39215686, 0.42745098],
#           [0.17254902, 0.13333333, 0.16470588],
#           [0.10196078, 0.05882353, 0.08235294],
#           ...,
#           [0.23921569, 0.21176471, 0.23921569],
#           [0.32941176, 0.30196078, 0.32941176],
#           [0.33333333, 0.30588235, 0.3372549 ]],
#
#          [[0.34117647, 0.31372549, 0.34117647],
#           [0.10980392, 0.0745098 , 0.09411765],
#           [0.0745098 , 0.03137255, 0.04705882],
#           ...,
#           [0.17254902, 0.14509804, 0.17254902],
#           [0.3254902 , 0.29803922, 0.3254902 ],
#           [0.3372549 , 0.30980392, 0.34117647]],
#
#          [[0.16470588, 0.1372549 , 0.16470588],
#           [0.08627451, 0.05098039, 0.07058824],
#           [0.08235294, 0.03921569, 0.05490196],
#           ...,
#           [0.07058824, 0.04313725, 0.07058824],
#           [0.3254902 , 0.29803922, 0.3254902 ],
#           [0.36470588, 0.3372549 , 0.36862745]],
#
#          ...,
#
# ...

# %%
plt.imshow(face[0]['face'])
plt.show()

# %%
face = DeepFace.extract_faces(  
    '../data/images_2.jpg',
    detector_backend='opencv'
)

plt.imshow(face[0]['face'])
plt.show()

# %%
face = DeepFace.extract_faces(  
    '../data/images_3.jpg',
    detector_backend='opencv'
)

plt.imshow(face[0]['face'])
plt.show()

# %%
results = DeepFace.verify(
    img1_path='../data/images_1.jpg',
    img2_path='../data/images_2.jpg',
    model_name='Facenet'
)

results
# Out:
# {'verified': True,
#  'distance': 0.3956141431622906,
#  'threshold': 0.4,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 65,
#    'y': 30,
#    'w': 74,
#    'h': 74,
#    'left_eye': (113, 57),
#    'right_eye': (87, 59)},
#   'img2': {'x': 829,
#    'y': 274,
#    'w': 596,
#    'h': 596,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 3.0}

# %%
results = DeepFace.verify(
    img1_path='../data/images_2.jpg',
    img2_path='../data/images_3.jpg',
    model_name='Facenet'
)

results
# Out:
# {'verified': True,
#  'distance': 0.24929897384472066,
#  'threshold': 0.4,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 829,
#    'y': 274,
#    'w': 596,
#    'h': 596,
#    'left_eye': None,
#    'right_eye': None},
#   'img2': {'x': 58,
#    'y': 47,
#    'w': 128,
#    'h': 128,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 3.02}
