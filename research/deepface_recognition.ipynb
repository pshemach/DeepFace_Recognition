# %%
from deepface import DeepFace
import matplotlib.pyplot as plt

# %%
face_1 = DeepFace.extract_faces(  
    '../data/test_images/download.jpg',
    detector_backend='opencv'
)

# %%
face_1
# Out:
# [{'face': array([[[0.37254902, 0.34117647, 0.39215686],
#           [0.41568627, 0.38823529, 0.42745098],
#           [0.09411765, 0.05882353, 0.09411765],
#           ...,
#           [0.33333333, 0.30588235, 0.33333333],
#           [0.36078431, 0.33333333, 0.36078431],
#           [0.38431373, 0.35686275, 0.38823529]],
#
#          [[0.40392157, 0.37647059, 0.41176471],
#           [0.28235294, 0.24705882, 0.27843137],
#           [0.07058824, 0.02745098, 0.05098039],
#           ...,
#           [0.3372549 , 0.30980392, 0.3372549 ],
#           [0.32941176, 0.30196078, 0.32941176],
#           [0.38431373, 0.35686275, 0.38823529]],
#
#          [[0.35294118, 0.3254902 , 0.35294118],
#           [0.11372549, 0.0745098 , 0.10196078],
#           [0.08235294, 0.03529412, 0.04313725],
#           ...,
#           [0.3254902 , 0.29803922, 0.3254902 ],
#           [0.3372549 , 0.30980392, 0.3372549 ],
#           [0.38431373, 0.35686275, 0.38431373]],
#
#          ...,
#
# ...

# %%
plt.imshow(face_1[0]['face'])
plt.show()

# %%
face_2 = DeepFace.extract_faces(  
    '../data/test_images/download_2.jpg',
    detector_backend='opencv'
)

plt.imshow(face_2[0]['face'])
plt.show()

# %%
face_3 = DeepFace.extract_faces(  
    '../data/test_images/download_3.jpg',
    detector_backend='opencv'
)

plt.imshow(face_3[0]['face'])
plt.show()

# %%
results = DeepFace.verify(
    img1_path='../data/test_images/download.jpg',
    img2_path='../data/test_images/download_2.jpg',
    model_name='Facenet512',
    distance_metric='euclidean_l2'
)

results
# Out:
# {'verified': True,
#  'distance': 1.0224896345199417,
#  'threshold': 1.04,
#  'model': 'Facenet512',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'euclidean_l2',
#  'facial_areas': {'img1': {'x': 64,
#    'y': 30,
#    'w': 75,
#    'h': 75,
#    'left_eye': (114, 58),
#    'right_eye': (86, 59)},
#   'img2': {'x': 54,
#    'y': 41,
#    'w': 130,
#    'h': 130,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 0.49}

# %%
from PIL import Image

# %%
results = DeepFace.verify(
    img1_path='../data/test_images/download_3.jpg',
    img2_path='../data/test_images/download_2.jpg',
    model_name='Facenet512',
    distance_metric='euclidean_l2'
)

results
# Out:
# {'verified': True,
#  'distance': 0.985398918573181,
#  'threshold': 1.04,
#  'model': 'Facenet512',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'euclidean_l2',
#  'facial_areas': {'img1': {'x': 91,
#    'y': 23,
#    'w': 65,
#    'h': 65,
#    'left_eye': None,
#    'right_eye': None},
#   'img2': {'x': 54,
#    'y': 41,
#    'w': 130,
#    'h': 130,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 0.45}

# %%
models = [
  "VGG-Face", 
  "Facenet", 
  "Facenet512", 
  "OpenFace", 
  "DeepFace", 
  "DeepID", 
  "ArcFace", 
  "Dlib", 
  "SFace",
  "GhostFaceNet",
]


result = DeepFace.verify(
  img1_path='../data/images_2.jpg',
  img2_path='../data/images_3.jpg',
  model_name = models[0],
)
# Out:
# 24-08-01 09:48:10 - vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: C:\Users\PC\.deepface\weights\vgg_face_weights.h5
# 100%|██████████| 580M/580M [03:26<00:00, 2.80MB/s]

# %%
result
# Out:
# {'verified': True,
#  'distance': 0.44298624207950343,
#  'threshold': 0.68,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 829,
#    'y': 274,
#    'w': 596,
#    'h': 596,
#    'left_eye': None,
#    'right_eye': None},
#   'img2': {'x': 58,
#    'y': 47,
#    'w': 128,
#    'h': 128,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 217.56}

# %%
result = DeepFace.verify(
  img1_path='../data/images_2.jpg',
  img2_path='../data/images_3.jpg',
  model_name = models[3],
)
# Out:
# 24-08-01 09:52:47 - openface_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/openface_weights.h5
# To: C:\Users\PC\.deepface\weights\openface_weights.h5
# 100%|██████████| 15.3M/15.3M [00:06<00:00, 2.42MB/s]

# %%
result
# Out:
# {'verified': False,
#  'distance': 0.2570267685990658,
#  'threshold': 0.1,
#  'model': 'OpenFace',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 829,
#    'y': 274,
#    'w': 596,
#    'h': 596,
#    'left_eye': None,
#    'right_eye': None},
#   'img2': {'x': 58,
#    'y': 47,
#    'w': 128,
#    'h': 128,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 12.9}

# %%
metrics = ["cosine", "euclidean", "euclidean_l2"]

#face verification
result = DeepFace.verify(
  img1_path='../data/images_2.jpg',
  img2_path='../data/images_3.jpg', 
  distance_metric = metrics[1],
)

# %%
result
# Out:
# {'verified': True,
#  'distance': 0.9412611136974729,
#  'threshold': 1.17,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'euclidean',
#  'facial_areas': {'img1': {'x': 829,
#    'y': 274,
#    'w': 596,
#    'h': 596,
#    'left_eye': None,
#    'right_eye': None},
#   'img2': {'x': 58,
#    'y': 47,
#    'w': 128,
#    'h': 128,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 4.81}

# %%
objs = DeepFace.analyze(
  img_path='../data/images_2.jpg',
  actions = ['age', 'gender', 'race', 'emotion'],
)
# Out:
# Action: age:   0%|          | 0/4 [00:00<?, ?it/s]
# 24-08-01 09:56:19 - age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: C:\Users\PC\.deepface\weights\age_model_weights.h5
# 100%|██████████| 539M/539M [03:20<00:00, 2.68MB/s]
# Action: gender:  25%|██▌       | 1/4 [03:48<11:24, 228.21s/it]
# 24-08-01 10:00:07 - gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: C:\Users\PC\.deepface\weights\gender_model_weights.h5
# 100%|██████████| 537M/537M [03:05<00:00, 2.89MB/s]
# Action: race:  50%|█████     | 2/4 [07:03<06:57, 208.95s/it]
# 24-08-01 10:03:22 - race_model_single_batch.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/race_model_single_batch.h5
# ...

# %%
objs
# Out:
# [{'age': 26,
#   'region': {'x': 829,
#    'y': 274,
#    'w': 596,
#    'h': 596,
#    'left_eye': None,
#    'right_eye': None},
#   'face_confidence': 0.88,
#   'gender': {'Woman': 0.665265740826726, 'Man': 99.33473467826843},
#   'dominant_gender': 'Man',
#   'race': {'asian': 2.8620496235519424,
#    'indian': 80.03415942395684,
#    'black': 6.880301647204259,
#    'white': 0.27897937023516717,
#    'middle eastern': 0.18616449033331814,
#    'latino hispanic': 9.758349344631991},
#   'dominant_race': 'indian',
#   'emotion': {'angry': 2.254038020685703e-11,
#    'disgust': 1.8115256381265915e-23,
#    'fear': 9.157647078403115e-16,
#    'happy': 100.0,
#    'sad': 7.896880226317962e-14,
#    'surprise': 2.7533055825220473e-13,
#    'neutral': 3.5830085426402647e-09},
#   'dominant_emotion': 'happy'}]

# %%
objs = DeepFace.analyze(
  img_path='../data/images_1.jpg',
  actions = ['age', 'gender', 'race', 'emotion'],
)
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:08<00:00,  2.19s/it]

# %%
objs
# Out:
# [{'age': 27,
#   'region': {'x': 65,
#    'y': 30,
#    'w': 74,
#    'h': 74,
#    'left_eye': (113, 57),
#    'right_eye': (87, 59)},
#   'face_confidence': 0.91,
#   'gender': {'Woman': 0.11200889712199569, 'Man': 99.88798499107361},
#   'dominant_gender': 'Man',
#   'race': {'asian': 2.352982386946678,
#    'indian': 80.47107458114624,
#    'black': 3.842081129550934,
#    'white': 0.8342763409018517,
#    'middle eastern': 1.0533981025218964,
#    'latino hispanic': 11.446195095777512},
#   'dominant_race': 'indian',
#   'emotion': {'angry': 2.010541968047619,
#    'disgust': 6.690903386896707e-07,
#    'fear': 0.10557688074186444,
#    'happy': 5.483295768499374,
#    'sad': 4.247785359621048,
#    'surprise': 0.16438525635749102,
#    'neutral': 87.98841834068298},
#   'dominant_emotion': 'neutral'}]

# %%
backends = [
  'opencv', 
  'ssd', 
  'dlib', 
  'mtcnn', 
  'fastmtcnn',
  'retinaface', 
  'mediapipe',
  'yolov8',
  'yunet',
  'centerface',
]

alignment_modes = [True, False]

#face verification
obj = DeepFace.verify(
  img1_path='../data/images_2.jpg',
  img2_path='../data/images_3.jpg', 
  detector_backend = backends[0],
  align = alignment_modes[0],
)

#face recognition
# dfs = DeepFace.find(
#   img_path = "img.jpg", 
#   db_path = "my_db", 
#   detector_backend = backends[1],
#   align = alignment_modes[0],
# )

#embeddings
# embedding_objs = DeepFace.represent(
#   img_path = "img.jpg", 
#   detector_backend = backends[2],
#   align = alignment_modes[0],
# )

#facial analysis
demographies = DeepFace.analyze(
  img_path='../data/images_2.jpg',
  detector_backend = backends[3],
  align = alignment_modes[0],
)

#face detection and alignment
face_objs = DeepFace.extract_faces(
  img_path='../data/images_2.jpg',
  detector_backend = backends[3],
  align = alignment_modes[0],
)
# Out:
# ...
# 1/1 [==============================] - 0s 47ms/step

# %%
obj
# Out:
# {'verified': True,
#  'distance': 0.44298624207950343,
#  'threshold': 0.68,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 829,
#    'y': 274,
#    'w': 596,
#    'h': 596,
#    'left_eye': None,
#    'right_eye': None},
#   'img2': {'x': 58,
#    'y': 47,
#    'w': 128,
#    'h': 128,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 25.76}

# %%
demographies
# Out:
# [{'emotion': {'angry': 2.973229160698872e-16,
#    'disgust': 5.25268859659982e-35,
#    'fear': 5.509374979779601e-22,
#    'happy': 100.0,
#    'sad': 2.12208778828778e-17,
#    'surprise': 1.0573139315823223e-20,
#    'neutral': 7.303487324652021e-15},
#   'dominant_emotion': 'happy',
#   'region': {'x': 875,
#    'y': 260,
#    'w': 446,
#    'h': 625,
#    'left_eye': (1237, 498),
#    'right_eye': (1031, 509)},
#   'face_confidence': 1.0,
#   'age': 28,
#   'gender': {'Woman': 1.1533303186297417, 'Man': 98.8466739654541},
#   'dominant_gender': 'Man',
#   'race': {'asian': 1.8128985539078712,
#    'indian': 75.35391449928284,
#    'black': 6.675601005554199,
#    'white': 1.764928549528122,
#    'middle eastern': 1.518658734858036,
#    'latino hispanic': 12.873992323875427},
#   'dominant_race': 'indian'}]

# %%
face_objs
# Out:
# [{'face': array([[[0.08235294, 0.08235294, 0.08235294],
#           [0.10196078, 0.10196078, 0.10196078],
#           [0.05490196, 0.05490196, 0.05490196],
#           ...,
#           [0.14901961, 0.14901961, 0.14117647],
#           [0.18823529, 0.18823529, 0.18039216],
#           [0.38039216, 0.38039216, 0.37254902]],
#
#          [[0.08627451, 0.08627451, 0.08627451],
#           [0.09411765, 0.09411765, 0.09411765],
#           [0.10980392, 0.10980392, 0.10980392],
#           ...,
#           [0.10588235, 0.10588235, 0.09803922],
#           [0.09411765, 0.09411765, 0.08627451],
#           [0.22745098, 0.22745098, 0.21960784]],
#
#          [[0.14509804, 0.14509804, 0.14509804],
#           [0.15686275, 0.15686275, 0.15686275],
#           [0.16078431, 0.16078431, 0.16078431],
#           ...,
#           [0.09019608, 0.09019608, 0.08235294],
#           [0.12156863, 0.12156863, 0.11372549],
#           [0.10196078, 0.10196078, 0.09411765]],
#
#          ...,
#
# ...
